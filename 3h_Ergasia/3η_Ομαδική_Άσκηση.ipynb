# %% [markdown]
# <h1><center>3η Εργαστηριακή Άσκηση του μαθήματος Τεχνολογία και Ανάλυση Εικόνων και Βίντεο</center></h1>
#
# <h2><center>Ακαδημιακό Έτος: 2020-2021</center></h2>
# <br>
#
# <h3>Επιμέλεια:</h3>
#
# <ul>
# <li><h3>Περόγαμβρος Γεώργιος 03117024</h3></li>
# <li><h3>Μπέτζελος Γεώργιος 03117442</h3></li>
# </ul>

# %% [markdown]
# <h1>1. Θεωρητικό μέρος</h1>
#
# <b>1.   Γιατί και πώς τα συνελικτικά δίκτυα άλλαξαν το τοπίο της παραδοσιακής επεξεργασίας
# εικόνας;</b>
#
# Πριν την εμφάνιση των συνελικτικών δικτύων, η δημιουργία δικτύων αναγνώρισης εικόνων απαιτούσε έντονη προεπεξεργασία του δικτύου και ορισμό αρκετών παραμέτρων πριν την έναρξη του αλγορίθμου εκμάθησης. Με τα συνελικτικά δίκτυα μπορούμε να έχουμε δίκτυα, τα οποία εξακολουθούν να έχουν καλή γενίκευση χωρίς να απαιτούν παραπάνω χρόνο εκμάθησης και έχοντας πολύ καλά error και reject rates, με ελάχιστη προεπεξεργασία, απλά παρέχοντας κατευθείαν τις εικόνες στο στάδιο της εκμάθησης. Αυτό επιτεύχθηκε μέσω της αρχιτεκτονικής των συλεκτικών δικτύων και τη χρήση κατάλληλων βαρών, τα οποία βοήθησαν το σύστημα να αποκτήσει χρήσιμη γνώση σχετικά με την εκάστοτε εργασία, μόνο μέσω της εκμάθησής του με χαμηλού επιπέδου δεδομένα τα οποία δεν είχαν περάσει από κάποια ιδιαίτερη προεπεξεργασία.
#
# <b>2. Περιγράψτε τη λειτουργία της Rectified Linear Unit (ReLU).</b>
#
# Οι ReLUs αναφέρονται σε νευρώνες που χρησιμοποιούν μη γραμμικές συναρτήσεις όπως η f(x) = max(0,x), οι οποίες σε αντίθεση με τις πιο συμβατικές γραμμικές συναρτήσεις, όπως η f(x) = tanh(x), έχουν ταχύτερο χρόνο εκπαίδευσης. Αυτό οφείλεται στο γεγονός πως αρκεί τουλάχιστον μερικά από τα εκπαιδευτικά παραδείγματα να έχουν θετικό αποτέλεσμα στο ReLU για να εκπαιδευτεί ο εκάστοτε νευρώνας. Επίσης, δεν είναι απαραίτητη η κανονικοποίηση της εισόδου, αφού δεν υπάρχει κίνδυνος κορεσμού του ReLU. Παρόλα αυτά συνίσταται η εφαρμογή τοπικής κανονικοποίησης, η οποία βασίζεται στη λειτουργία των πραγματικών νευρώνων, όπου η υπερδιέργερση ενός νευρώνα δεν μεταδίδεται στους γειτονικούς νευρώνες. Έτσι και στο δίκτυο η κανονικοποίηση αυτή προωθεί την ανταγωνιστικότητα μεταξύ των αποτελέσματων των νευρώνων που χρησιμοποιούν διαφορετικούς πυρήνες.
#
# <b>3. Παρουσιάστε ένα συγκριτικό πίνακα με τα επίπεδα, το μέγεθος των φίλτρων, συνάρτηση
# ενεργοποίησης, πλήθος παραμέτρων και τεχνικές pooling και dropout που χρησιμοποιούν
# τα 3 διαφορετικά δίκτυα που παρουσιάζονται στα προαναφερθέντα άρθρα και σχολιάστε
# επαρκώς τις διαφορές τους. Ποια χαρακτηριστικά αυτών των τριών δικτύων είναι κατά τη
# γνώμη σας αυτά που συνέβαλαν στη σταδιακή αύξηση της ακρίβειας ταξινόμησης.</b>

# %% [markdown]
# Παραθέτουμε τον πίνακα με τα στοιχεία των τριών διαφορετικών δικτύων:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Το LeNet είναι το πιο απλό και μικρό από τα τρία δίκτυα, με λίγα φίλτρα και το μόνο που χρησίμοποιει Average Pooling Layers και sigmoid συνάρτηση ενεργοποίησης. Το AlexNet, ακολουθεί τη βασική φιλοσοφία του LeNet, αλλά είναι μεγαλύτερο με περισσότερα layers και φίλτρα και γενικά προορίζεται για μεγαλύτερου μεγέθους εικόνες. Τέλος, το VGG μπορεί να έχει περισσότερα ή λιγότερα layers ανάλογα του πλήθους των Convolutional-Pooling blocks που θα χρησιμοποιεί, καθώς επίσης ούτε ο αριθμός των φίλτρων είναι σταθερός. Σύνηθη VGG δίκτυα είναι τα VGG16, VGG19 που έχουν 16 και 19 τέτοια blocks αντίστοιχα και είναι αρκετά βαριά και "ακριβά" δίκτυα. <br/>
# Το βασικότερο χαρακτηριστικό των τριών αυτών δικτύων που συνέβαλε στη σταδιακή αύξηση της ακρίβειας ταξινόμησης είναι πως δεν είναι αναγκαίο κάποιο βαρύ preprossecing στο input dataset προκειμένου να έχουμε καλά και γενικευμένα αποτελέσματα, χαρακτηριστικό το οποίο πρωτοεμφανίστηκε στο LeNet. Ένα ακόμα χαρακτηριστικό που θεωρούμε σημαντικό είναι η εμφάνιση τεχνικών όπως η Dropout, η οποία χρησιμοποιείται στο AlexNet και το VGG και έχει σκοπό την προστασία από την υπερεκπαίδευση και την καλύτερη γενίκευση του δικτύου. Τέλος, το VGG έλυσε το πρόβλημα του AlexNet, το οποίο έχει πάρα πολλές υπερπαραμέτρους, αντικαθιστώντας τα μεγάλα φίτλρα και kernels με πολλά 3x3 kernels το ένα μετά το άλλο.

# %% [markdown]
# ## Εισαγωγή και επισκόπηση του συνόλου δεδομένων

# %%
from __future__ import absolute_import, division, print_function, unicode_literals # legacy compatibility

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy
import cv2

# %%
# helper functions

# select from from_list elements with index in index_list
def select_from_list(from_list, index_list):
  filtered_list= [from_list[i] for i in index_list]
  return(filtered_list)

# append in filtered_list the index of each element of unfilterd_list if it exists in in target_list
def get_ds_index(unfiliterd_list, target_list):
  index = 0
  filtered_list=[]
  for i_ in unfiliterd_list:
    if i_[0] in target_list:
      filtered_list.append(index)
    index += 1
  return(filtered_list)

# %%
# load the entire dataset
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

(x_train_all, y_train_all), (x_test_all, y_test_all) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
# Out:
# ...
# 169009152/169001437 [==============================] - 5s 0us/step

# %%
print(x_train_all.shape)
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# Η κάθε ομάδα θα δουλέψει με διαφορετικό υποσύνολο του dataset.
# Στο επόμενο κελί, αντικαταστήστε την τιμή της μεταβλητής `team_seed` με τον αριθμό που αντιστοιχεί στην ομάδας σας.

# %%
# REPLACE WITH YOUR TEAM NUMBER
team_seed = 26

# %%
# select from CIFAR100 20 classes
cifar100_classes_url = "https://pastebin.com/raw/nzE1n98V"

# %% [markdown]
# Δημιουργούμε το μοναδικό dataset της ομάδας μας:

# %%
team_classes = pd.read_csv(cifar100_classes_url, sep=',', header=None)
CIFAR100_LABELS_LIST = pd.read_csv('https://pastebin.com/raw/qgDaNggt', sep=',', header=None).astype(str).values.tolist()[0]

our_index = team_classes.iloc[team_seed,:].values.tolist()
our_classes = select_from_list(CIFAR100_LABELS_LIST, our_index)
train_index = get_ds_index(y_train_all, our_index)
test_index = get_ds_index(y_test_all, our_index)

x_train_ds = np.asarray(select_from_list(x_train_all, train_index))
y_train_ds = np.asarray(select_from_list(y_train_all, train_index))
x_test_ds = np.asarray(select_from_list(x_test_all, test_index))
y_test_ds = np.asarray(select_from_list(y_test_all, test_index))

# %%
# print our classes
print(our_classes)
# Out:
# [' bus', ' chimpanzee', ' cloud', ' dinosaur', ' forest', ' fox', ' girl', ' hamster', ' lobster', ' motorcycle', ' oak_tree', ' pine_tree', ' seal', ' shrew', ' skunk', ' snake', ' sweet_pepper', ' telephone', ' tiger', ' worm']

# %%
print(x_train_ds[1].shape)
# Out:
# (32, 32, 3)

# %%
# get (train) dataset dimensions
data_size, img_rows, img_cols, img_channels = x_train_ds.shape

# set validation set percentage (wrt the training set size)
validation_percentage = 0.15
val_size = round(validation_percentage * data_size)

# Reserve val_size samples for validation and normalize all values
x_val = x_train_ds[-val_size:]/255
y_val = y_train_ds[-val_size:]
x_train = x_train_ds[:-val_size]/255
y_train = y_train_ds[:-val_size]
x_test = x_test_ds/255
y_test = y_test_ds

# summarize loaded dataset
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

# get class label from class index
def class_label_from_index(fine_category):
  return(CIFAR100_LABELS_LIST[fine_category.item(0)])

# plot first few images
plt.figure(figsize=(6, 6))
for i in range(9):
	# define subplot
  plt.subplot(330 + 1 + i).set_title(class_label_from_index(y_train[i]))
	# plot raw pixel data
  plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
  #show the figure
plt.show()
# Out:
# Train: X=(8500, 32, 32, 3), y=(8500, 1)
# Validation: X=(1500, 32, 32, 3), y=(1500, 1)
# Test: X=(2000, 32, 32, 3), y=(2000, 1)

# %%
#Mapping the values of the original 20 classes to a [0,19] range

vals = []
j = 0
flag = 1

for i in y_val:
  for t in vals:
    if i == t[0]:
      flag = 0
  if flag == 1:
    vals.append((copy.deepcopy(i), np.array([j])))
    j += 1
  flag = 1
    
print(len(vals))
print(vals)
# Out:
# 20
# [(array([29]), array([0])), (array([48]), array([1])), (array([34]), array([2])), (array([83]), array([3])), (array([52]), array([4])), (array([74]), array([5])), (array([75]), array([6])), (array([45]), array([7])), (array([13]), array([8])), (array([88]), array([9])), (array([23]), array([10])), (array([36]), array([11])), (array([78]), array([12])), (array([21]), array([13])), (array([86]), array([14])), (array([72]), array([15])), (array([33]), array([16])), (array([35]), array([17])), (array([59]), array([18])), (array([99]), array([19]))]

# %%
#Since we don't need to print the name of each class we can replace the original values with the new ones. If we needed the original values so we could print the class names we would do the mapping in new lists

for i in range(len(y_val)):
  for j in vals:
    if y_val[i] == j[0]:
      y_val[i] = j[1]

for i in range(len(y_train)):
  for j in vals:
    if y_train[i] == j[0]:
      y_train[i] = j[1]

for i in range(len(y_test)):
  for j in vals:
    if y_test[i] == j[0]:
      y_test[i] = j[1]

# %%
#Resizing images
x_val_res = []
for i in range(len(x_val)):
  x_val_res.append(cv2.resize(x_val[i], (96,96)))

x_train_res = []
for i in range(len(x_train)):
  x_train_res.append(cv2.resize(x_train[i], (96,96)))

x_test_res = []
for i in range(len(x_test)):
  x_test_res.append(cv2.resize(x_test[i], (96,96)))

x_test_res = np.asarray(x_test_res)
x_val_res = np.asarray(x_val_res)
x_train_res = np.asarray(x_train_res)

# %% [markdown]
# ## Ερώτημα 1
# ---
# #### Βήμα 1: Σχεδίαση, μεταγλώττιση και εκπαίδευση των μοντέλων
#
#  1. Σχεδίαστε, μεταγλωττίστε και εκπαιδεύστε τα μοντέλα  **LeNet, AlexNet και  VGG**, καθώς και ένα δικό σας μοντέλο (ονομάστε το π.χ. **MyCNN**) χρησιμοποιώντας διαφορετικούς συνδυασμούς (τουλάχιστον 2 ανά μοντέλο) για [optimizer](https://keras.io/api/optimizers/), [loss](https://keras.io/api/losses/), batch size και epoch.  Για [metrics](https://keras.io/api/metrics/) να χρησιμοποιήσετε την ορθότητα (όπως στο Lab9.1).
# ---
#
# #### Βήμα 2: Αξιολόγηση των μοντέλων
#
# 1. Για κάθε ένα από τα μοντέλα που εκπαιδεύσατε, απεικονίστε σε κοινό διάγραμμα την ορθότητα εκπαίδευσης και την ορθότητα επικύρωσης στο σύνολο των εποχών, για κάθε διαφορετικό συνδυασμό του βήματος 1 και επιλέξτε αυτό με την καλύτερη ορθότητα από κάθε μοντέλο (ένα από κάθε αρχιτεκτονική, συνολικά 4).
# 2. Για κάθε ένα από τα μοντέλα με την καλύτερη ορθότητα (συνολικά **4**), απεικονίστε σε κοινό διάγραμμα την ορθότητα εκπαίδευσης και την ορθότητα επικύρωσης στο σύνολο των εποχών.
# 3. Αξιολογήστε, αναλυτικά, τα αποτελέσματά σας ως προς τα εξής:
#  - Επίδραση του πλήθους των δεδομένων/κλάσεων στην απόδοση του μοντέλου
#  - Επίδραση του αλγόριθμου βελτιστοποίησης (optimizer)
#  - Επίδραση του μεγέθους δέσμης (batch size)
#
# ---
#
# #### Βήμα 3: Αξιολόγηση ορθότητας
# Αξιολογήστε την ορθότητα για το test set σας.

# %% [markdown]
# To test του κάθε CNN παρουσιάζεται μετά από τη διαδικασία μάθησής του.

# %%
#Lenet1

Lenet_model1 = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters=6, kernel_size=5, activation='sigmoid',
                               padding='same'),
        tf.keras.layers.AvgPool2D(pool_size=2, strides=2),
        tf.keras.layers.Conv2D(filters=16, kernel_size=5,
                               activation='sigmoid'),
        tf.keras.layers.AvgPool2D(pool_size=2, strides=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(120, activation='sigmoid'),
        tf.keras.layers.Dense(84, activation='sigmoid'),
        tf.keras.layers.Dense(20)])


Lenet_model1.compile(optimizer='nadam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


Lenet_history1 = Lenet_model1.fit(x_train, y_train, epochs=20, batch_size=128,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 67/67 [==============================] - 1s 9ms/step - loss: 3.0177 - accuracy: 0.0482 - val_loss: 3.0104 - val_accuracy: 0.0413
# Epoch 2/20
# 67/67 [==============================] - 0s 6ms/step - loss: 3.0019 - accuracy: 0.0489 - val_loss: 3.0018 - val_accuracy: 0.0513
# Epoch 3/20
# 67/67 [==============================] - 0s 6ms/step - loss: 2.9929 - accuracy: 0.0614 - val_loss: 2.9496 - val_accuracy: 0.0780
# Epoch 4/20
# 67/67 [==============================] - 0s 6ms/step - loss: 2.8600 - accuracy: 0.1241 - val_loss: 2.7708 - val_accuracy: 0.1607
# Epoch 5/20
# 67/67 [==============================] - 0s 6ms/step - loss: 2.7146 - accuracy: 0.1655 - val_loss: 2.6788 - val_accuracy: 0.1787
# Epoch 6/20
# 67/67 [==============================] - 0s 6ms/step - loss: 2.6249 - accuracy: 0.1965 - val_loss: 2.6081 - val_accuracy: 0.1960
# Epoch 7/20
# ...

# %%
test_loss, test_acc = Lenet_model1.evaluate(x_test,  y_test, verbose=2)
print(test_loss, test_acc)
# Out:
# 63/63 - 0s - loss: 2.2302 - accuracy: 0.3075
# 2.2302138805389404 0.3075000047683716

# %%
#Lenet2
Lenet_model2 = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters=6, kernel_size=5, activation='sigmoid',
                               padding='same'),
        tf.keras.layers.AvgPool2D(pool_size=2, strides=2),
        tf.keras.layers.Conv2D(filters=16, kernel_size=5,
                               activation='sigmoid'),
        tf.keras.layers.AvgPool2D(pool_size=2, strides=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(120, activation='sigmoid'),
        tf.keras.layers.Dense(84, activation='sigmoid'),
        tf.keras.layers.Dense(20)])


Lenet_model2.compile(optimizer=tf.keras.optimizers.SGD(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


Lenet_history2 = Lenet_model2.fit(x_train, y_train, epochs=12, batch_size=100,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/12
# 71/71 [==============================] - 1s 7ms/step - loss: 3.0486 - accuracy: 0.0487 - val_loss: 3.0215 - val_accuracy: 0.0460
# Epoch 2/12
# 71/71 [==============================] - 0s 5ms/step - loss: 3.0062 - accuracy: 0.0508 - val_loss: 3.0032 - val_accuracy: 0.0460
# Epoch 3/12
# 71/71 [==============================] - 0s 5ms/step - loss: 2.9982 - accuracy: 0.0475 - val_loss: 2.9997 - val_accuracy: 0.0413
# Epoch 4/12
# 71/71 [==============================] - 0s 5ms/step - loss: 2.9968 - accuracy: 0.0475 - val_loss: 2.9987 - val_accuracy: 0.0413
# Epoch 5/12
# 71/71 [==============================] - 0s 4ms/step - loss: 2.9965 - accuracy: 0.0484 - val_loss: 2.9982 - val_accuracy: 0.0380
# Epoch 6/12
# 71/71 [==============================] - 0s 5ms/step - loss: 2.9964 - accuracy: 0.0481 - val_loss: 2.9979 - val_accuracy: 0.0413
# Epoch 7/12
# ...

# %%
test_loss, test_acc = Lenet_model2.evaluate(x_test,  y_test, verbose=2)
print(test_loss, test_acc)
# Out:
# 63/63 - 0s - loss: 2.9959 - accuracy: 0.0500
# 2.995924711227417 0.05000000074505806

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Στην περίπτωση του Lenet καλύτερο είναι το πρώτο CNN, καθώς έχει πολύ καλύτερη ορθότητα εκπαίδευσης αλλά και ορθότητα επικύρωσης.

# %%
#Alexnet1

Alexnet_model1 = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters=96, kernel_size=11, strides=4,
                               activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        tf.keras.layers.Conv2D(filters=256, kernel_size=5, padding='same',
                               activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        tf.keras.layers.Conv2D(filters=384, kernel_size=3, padding='same',
                               activation='relu'),
        tf.keras.layers.Conv2D(filters=384, kernel_size=3, padding='same',
                               activation='relu'),
        tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same',
                               activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(20)])

Alexnet_model1.compile(optimizer=tf.keras.optimizers.Adadelta(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


Alexnet_history1 = Alexnet_model1.fit(x_train_res, y_train, epochs=10, batch_size=85,
                    validation_data=(x_val_res, y_val))
# Out:
# Epoch 1/10
# 100/100 [==============================] - 8s 65ms/step - loss: 2.9959 - accuracy: 0.0528 - val_loss: 2.9960 - val_accuracy: 0.0487
# Epoch 2/10
# 100/100 [==============================] - 6s 60ms/step - loss: 2.9959 - accuracy: 0.0551 - val_loss: 2.9959 - val_accuracy: 0.0480
# Epoch 3/10
# 100/100 [==============================] - 6s 61ms/step - loss: 2.9957 - accuracy: 0.0553 - val_loss: 2.9958 - val_accuracy: 0.0440
# Epoch 4/10
# 100/100 [==============================] - 6s 61ms/step - loss: 2.9956 - accuracy: 0.0525 - val_loss: 2.9958 - val_accuracy: 0.0447
# Epoch 5/10
# 100/100 [==============================] - 6s 61ms/step - loss: 2.9955 - accuracy: 0.0522 - val_loss: 2.9957 - val_accuracy: 0.0447
# Epoch 6/10
# 100/100 [==============================] - 6s 60ms/step - loss: 2.9955 - accuracy: 0.0520 - val_loss: 2.9957 - val_accuracy: 0.0407
# Epoch 7/10
# ...

# %%
test_loss, test_acc = Alexnet_model1.evaluate(x_test_res,  y_test, verbose=2)
print(test_loss, test_acc)
# Out:
# 63/63 - 1s - loss: 2.9952 - accuracy: 0.0540
# 2.995157480239868 0.05400000140070915

# %%
#Alexnet2

Alexnet_model2 = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters=96, kernel_size=11, strides=4,
                               activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        tf.keras.layers.Conv2D(filters=256, kernel_size=5, padding='same',
                               activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        tf.keras.layers.Conv2D(filters=384, kernel_size=3, padding='same',
                               activation='relu'),
        tf.keras.layers.Conv2D(filters=384, kernel_size=3, padding='same',
                               activation='relu'),
        tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same',
                               activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(20)])

Alexnet_model2.compile(optimizer=tf.keras.optimizers.Ftrl(),
              loss=tf.keras.losses.KLDivergence(),
              metrics=['accuracy'])


Alexnet_history2 = Alexnet_model2.fit(x_train_res, y_train, epochs=18, batch_size=150,
                    validation_data=(x_val_res, y_val))
# Out:
# Epoch 1/18
# 57/57 [==============================] - 39s 109ms/step - loss: 4.8293 - accuracy: 0.0508 - val_loss: 0.0215 - val_accuracy: 0.0460
# Epoch 2/18
# 57/57 [==============================] - 5s 89ms/step - loss: 0.0197 - accuracy: 0.0508 - val_loss: 0.0123 - val_accuracy: 0.0460
# Epoch 3/18
# 57/57 [==============================] - 5s 89ms/step - loss: 0.0122 - accuracy: 0.0500 - val_loss: 0.0091 - val_accuracy: 0.0460
# Epoch 4/18
# 57/57 [==============================] - 5s 90ms/step - loss: 0.0091 - accuracy: 0.0505 - val_loss: 0.0073 - val_accuracy: 0.0460
# Epoch 5/18
# 57/57 [==============================] - 5s 90ms/step - loss: 0.0079 - accuracy: 0.0507 - val_loss: 0.0061 - val_accuracy: 0.0460
# Epoch 6/18
# 57/57 [==============================] - 5s 90ms/step - loss: 0.0068 - accuracy: 0.0512 - val_loss: 0.0052 - val_accuracy: 0.0460
# Epoch 7/18
# ...

# %%
test_loss, test_acc = Alexnet_model2.evaluate(x_test_res,  y_test, verbose=2)
print(test_loss, test_acc)
# Out:
# 63/63 - 1s - loss: 1.1224e-04 - accuracy: 0.0500
# 0.0001122406029026024 0.05000000074505806

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Αν και οι δύο εκδοχές του μοντέλου έχουν πολύ κακές ορθότητες, καλύτερη θεωρούμε την πρώτη εκδοχή καθώς παρατηρείται μια κάπως υψηλότερη ορθότητα και μια γενικά εντονότερη τάση για βελτίωσή της σε σύγκριση με τη δεύτερη εκδοχή. Δοκιμάσαμε και άλλους συνδυασμούς χωρίς να έχουμε καλύτερα αποτελέσματα (στις περισσότερες περιπτώσεις δεν παρατηρούσαμε καν μάθηση). Πιθανόν αυτό να οφείλεται στο ότι το AlexNet είναι φτιαγμένο για το ImageNet όπου οι εικόνες είναι αρκετά μεγαλύτερες (224x224) και διαφορετικές από αυτές του CIFAR-100.

# %%
#VGG1
num_convs = 3
VGG_model1=tf.keras.models.Sequential()
for _ in range(num_convs):
  VGG_model1.add(tf.keras.layers.Conv2D(50, kernel_size=3,padding='same', activation='relu'))
  VGG_model1.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
VGG_model1.add(
            tf.keras.models.Sequential([
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(4096, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(4096, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(20)]))

VGG_model1.compile(optimizer=tf.keras.optimizers.Nadam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


VGG_history1 = VGG_model1.fit(x_train, y_train, epochs=13, batch_size=100,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/13
# 85/85 [==============================] - 4s 27ms/step - loss: 2.7424 - accuracy: 0.1614 - val_loss: 2.5309 - val_accuracy: 0.2580
# Epoch 2/13
# 85/85 [==============================] - 2s 24ms/step - loss: 2.1058 - accuracy: 0.3468 - val_loss: 1.9037 - val_accuracy: 0.4027
# Epoch 3/13
# 85/85 [==============================] - 2s 25ms/step - loss: 1.7647 - accuracy: 0.4495 - val_loss: 1.6973 - val_accuracy: 0.4693
# Epoch 4/13
# 85/85 [==============================] - 2s 24ms/step - loss: 1.5289 - accuracy: 0.5193 - val_loss: 1.4768 - val_accuracy: 0.5407
# Epoch 5/13
# 85/85 [==============================] - 2s 24ms/step - loss: 1.3322 - accuracy: 0.5771 - val_loss: 1.4528 - val_accuracy: 0.5540
# Epoch 6/13
# 85/85 [==============================] - 2s 24ms/step - loss: 1.1842 - accuracy: 0.6235 - val_loss: 1.4182 - val_accuracy: 0.5667
# Epoch 7/13
# ...

# %%
test_loss, test_acc = VGG_model1.evaluate(x_test,  y_test, verbose=2)
print(test_loss, test_acc)
# Out:
# 63/63 - 0s - loss: 1.8393 - accuracy: 0.5985
# 1.8393409252166748 0.5985000133514404

# %%
#VGG2
num_convs = 3
VGG_model2=tf.keras.models.Sequential()
for _ in range(num_convs):
  VGG_model2.add(tf.keras.layers.Conv2D(50, kernel_size=3,padding='same', activation='relu'))
  VGG_model2.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
VGG_model2.add(
            tf.keras.models.Sequential([
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(4096, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(4096, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(20)]))

VGG_model2.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


VGG_history2 = VGG_model2.fit(x_train, y_train, epochs=20, batch_size=90,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 95/95 [==============================] - 2s 16ms/step - loss: 2.5884 - accuracy: 0.1887 - val_loss: 2.2527 - val_accuracy: 0.3193
# Epoch 2/20
# 95/95 [==============================] - 1s 13ms/step - loss: 1.9902 - accuracy: 0.3812 - val_loss: 1.8497 - val_accuracy: 0.4113
# Epoch 3/20
# 95/95 [==============================] - 1s 12ms/step - loss: 1.6902 - accuracy: 0.4726 - val_loss: 1.6510 - val_accuracy: 0.4880
# Epoch 4/20
# 95/95 [==============================] - 1s 13ms/step - loss: 1.5010 - accuracy: 0.5284 - val_loss: 1.5065 - val_accuracy: 0.5380
# Epoch 5/20
# 95/95 [==============================] - 1s 12ms/step - loss: 1.3282 - accuracy: 0.5759 - val_loss: 1.5055 - val_accuracy: 0.5247
# Epoch 6/20
# 95/95 [==============================] - 1s 13ms/step - loss: 1.1804 - accuracy: 0.6234 - val_loss: 1.4483 - val_accuracy: 0.5540
# Epoch 7/20
# ...

# %%
test_loss, test_acc = VGG_model2.evaluate(x_test,  y_test, verbose=2)
print(test_loss, test_acc)
# Out:
# 63/63 - 0s - loss: 2.1037 - accuracy: 0.6120
# 2.103696346282959 0.6119999885559082

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Αν και οι δύο εκδοχές είναι αρκετά καλές, καλύτερες ορθότητες παρατηρούνται στη 2η εκδοχή του VGG.

# %%
#MyCNN1

MyCNN_model1 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'), 
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dense(20, activation='relu')])

MyCNN_model1.compile(optimizer=tf.keras.optimizers.Nadam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


MyCNN_History1 = MyCNN_model1.fit(x_train, y_train, epochs=10, batch_size=90,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/10
# 95/95 [==============================] - 4s 36ms/step - loss: 2.8644 - accuracy: 0.1439 - val_loss: 2.7284 - val_accuracy: 0.2120
# Epoch 2/10
# 95/95 [==============================] - 1s 7ms/step - loss: 2.4797 - accuracy: 0.3000 - val_loss: 2.3811 - val_accuracy: 0.3380
# Epoch 3/10
# 95/95 [==============================] - 1s 6ms/step - loss: 2.2514 - accuracy: 0.3720 - val_loss: 2.3152 - val_accuracy: 0.3547
# Epoch 4/10
# 95/95 [==============================] - 1s 7ms/step - loss: 2.0990 - accuracy: 0.4211 - val_loss: 2.6638 - val_accuracy: 0.2993
# Epoch 5/10
# 95/95 [==============================] - 1s 7ms/step - loss: 1.9735 - accuracy: 0.4522 - val_loss: 2.0796 - val_accuracy: 0.4220
# Epoch 6/10
# 95/95 [==============================] - 1s 6ms/step - loss: 1.8183 - accuracy: 0.4962 - val_loss: 2.0639 - val_accuracy: 0.4173
# Epoch 7/10
# ...

# %%
test_loss, test_acc = MyCNN_model1.evaluate(x_test,  y_test, verbose=2)
print(test_loss, test_acc)
# Out:
# 63/63 - 0s - loss: 2.0704 - accuracy: 0.4420
# 2.0704431533813477 0.44200000166893005

# %%
#MyCNN2

MyCNN_model2 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'), 
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dense(20, activation='relu')])

MyCNN_model2.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


MyCNN_History2 = MyCNN_model2.fit(x_train, y_train, epochs=18, batch_size=128,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/18
# 67/67 [==============================] - 1s 9ms/step - loss: 2.6779 - accuracy: 0.2147 - val_loss: 2.4359 - val_accuracy: 0.2953
# Epoch 2/18
# 67/67 [==============================] - 0s 6ms/step - loss: 2.3518 - accuracy: 0.3204 - val_loss: 2.3404 - val_accuracy: 0.3387
# Epoch 3/18
# 67/67 [==============================] - 0s 6ms/step - loss: 2.1966 - accuracy: 0.3754 - val_loss: 2.2774 - val_accuracy: 0.3527
# Epoch 4/18
# 67/67 [==============================] - 0s 6ms/step - loss: 2.0720 - accuracy: 0.4124 - val_loss: 2.2481 - val_accuracy: 0.3660
# Epoch 5/18
# 67/67 [==============================] - 0s 6ms/step - loss: 2.0149 - accuracy: 0.4321 - val_loss: 2.1512 - val_accuracy: 0.3907
# Epoch 6/18
# 67/67 [==============================] - 0s 6ms/step - loss: 1.9242 - accuracy: 0.4596 - val_loss: 2.0991 - val_accuracy: 0.4067
# Epoch 7/18
# ...

# %%
test_loss, test_acc = MyCNN_model2.evaluate(x_test,  y_test, verbose=2)
print(test_loss, test_acc)
# Out:
# 63/63 - 0s - loss: 2.0794 - accuracy: 0.4605
# 2.0794384479522705 0.46050000190734863

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Στην περίπτωση του δικού μας μοντέλου καλύτερες ορθότητες είχαμε στη δεύτερη εκδοχή του.

# %% [markdown]
# Γενικά προσπαθήσαμε να πειραματιστούμε και περισσότερο με τις παραμέτρους για τα optimizer και loss, αλλά δεν καταφέραμε συνδυασμούς που να έχουν σχετικά καλή ορθότητα και δεν θεωρήσαμε πως αξίζει να τους παρουσιάσουμε (είτε σταθερές ορθότητες, απουσία μάθησης, είτε πολύ χαμηλές τιμές γύρω από το 0.05, το οποίο με 20 κατηγορίες είναι σαν τυχαία επιλογή).

# %% [markdown]
# Παρουσιάζουμε τις ορθότητες και τις ορθότητες επικύρωσης για τα 4 CNNs που επιλέξαμε
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Από τις δοκιμές που κάναμε για την επίδραση των παραμέτρων στην ορθότητα του CNN καταλήξαμε στα εξής συμπεράσματα:
#
#
# *   Για το LeNet, το VGG καθώς και το δικό μας δίκτυο το μικρό dataset καθώς και οι λίγες κατηγορίες δεν φάνηκαν να έχουν έντονη αρνητική επίδραση στην ορθότητα των CNN, αν και πιθανότατα με ένα μεγαλύτερο dataset να μπορούσαμε να πετύχουμε ακόμα καλύτερες τιμές. Στην περίπτωση του AlexNet, υποθέτουμε πως το είδος των δεδομένων (χαμηλής ανάλυσης και λίγες εικόνες) έπαιξαν σημαντικό ρόλο στη χαμηλή ορθότητά του, καθώς όσο και να πειραματιστήκαμε με τις υπόλοιπες παραμέτρους δεν καταφέραμε να επιτύχουμε ορθότητα πάνω από 5% (τυχαία επιλογή).
# *   Όσον αφορά τον optimizer είδαμε πολύ καλύτερα αποτελέσματα με τη χρήση των "adam" και "nadam". Προσπαθήσαμε να χρησιμοποιήσουμε και τους υπόλοιπους optimizers αλλά είχαμε είτε παρόμοια αποτελέσματα με αυτά του LeNet2 (SGD optimizer), είτε δεν παρατηρούσαμε καν μάθηση (σταθερό accuracy).
# *   Τέλος για το Batch Size, δεν βρήκαμε κάποια ιδανική τιμή που να είναι κοινή για όλα τα μοντέλα, αλλά σίγουρα παρατηρήσαμε πως επιδρά στο τελικό accyracy, πχ για το MyCNN1 με Batch Size = 25 η ορθότητα έφτανε μέχρι το 0.05, και πως γενικά το κάθε μοντέλο έχει μια "δικιά" του καλή τιμή για το Batch Size.

# %% [markdown]
# Για την ορθότητα των tests παρατηρούμε πως στις περισσότερες περιπτώσεις βρίσκεται μεταξύ της ορθότητας και της ορθότητας επικύρωσης και πιο κοντά στην ορθότητα επικύρωσης.

# %% [markdown]
# ## Ερώτημα 2
# ---
# ### Βήμα 1: Έλεγχος υπερεκπαίδευσης
#
# Για τον καλύτερο συνδυασμό που λάβατε από το Ερώτημα 1 για μοντέλο σας  (**MyCNN**) και μόνο, δοκιμάστε διάφορους συνδυασμούς των ακόλουθων τεχνικών για τον έλεγχο της υπερεκπαίδευσης (overfitting), όπως:
# - Πρόωρος τερματισμός (early stopping [tf.keras.callbacks.EarlyStopping](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStoppinghttps://))
#
# - Dropout ([Dropout](https://www.tensorflow.org/tutorials/images/classification#dropout))
#
# - Επαύξηση δεδομένων ([Data augmentation](https://www.tensorflow.org/tutorials/images/classification#data_augmentation), [ImageDataGenerator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator#class_imagedatagenerator))
#
# \\
# , ώστε το μοντέλο σας να γενικεύει καλύτερα.
#
# ---
# ### Βήμα 2: Αξιολόγηση
# Αξιολογήστε της ορθότητας για το validation και το test set σας.

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

MyCNN_hyper_learning_model1 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'), 
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(20, activation='relu')])

MyCNN_hyper_learning_model1.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


MyCNN_hyper_learning_History1 = MyCNN_hyper_learning_model1.fit(x_train, y_train, epochs=18, batch_size=128,
                    validation_data=(x_val, y_val), callbacks = [callback])

test_loss1, test_acc1 = MyCNN_hyper_learning_model1.evaluate(x_test,  y_test, verbose=2)
print(test_loss1, test_acc1)
# Out:
# Epoch 1/18
# 67/67 [==============================] - 2s 16ms/step - loss: 2.8697 - accuracy: 0.1333 - val_loss: 2.6355 - val_accuracy: 0.2387
# Epoch 2/18
# 67/67 [==============================] - 1s 11ms/step - loss: 2.5031 - accuracy: 0.2422 - val_loss: 2.2757 - val_accuracy: 0.3187
# Epoch 3/18
# 67/67 [==============================] - 1s 12ms/step - loss: 2.2472 - accuracy: 0.3135 - val_loss: 2.0926 - val_accuracy: 0.3913
# Epoch 4/18
# 67/67 [==============================] - 1s 11ms/step - loss: 2.0421 - accuracy: 0.3728 - val_loss: 1.8858 - val_accuracy: 0.4367
# Epoch 5/18
# 67/67 [==============================] - 1s 11ms/step - loss: 1.8959 - accuracy: 0.4239 - val_loss: 1.7796 - val_accuracy: 0.4560
# Epoch 6/18
# 67/67 [==============================] - 1s 10ms/step - loss: 1.7662 - accuracy: 0.4636 - val_loss: 1.6663 - val_accuracy: 0.5033
# Epoch 7/18
# ...

# %%
from tensorflow.keras import preprocessing

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)

MyCNN_hyper_learning_model2 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'), 
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(20, activation='relu')])

MyCNN_hyper_learning_model2.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


MyCNN_hyper_learning_History2 = MyCNN_hyper_learning_model2.fit(x_train, y_train, epochs=18, batch_size=128,
                    validation_data=(x_val, y_val), callbacks = [callback])

test_loss2, test_acc2 = MyCNN_hyper_learning_model2.evaluate(x_test,  y_test, verbose=2)
print(test_loss2, test_acc2)
# Out:
# Epoch 1/18
# 67/67 [==============================] - 2s 16ms/step - loss: 2.8141 - accuracy: 0.1440 - val_loss: 2.4664 - val_accuracy: 0.2733
# Epoch 2/18
# 67/67 [==============================] - 1s 12ms/step - loss: 2.3083 - accuracy: 0.3019 - val_loss: 2.0824 - val_accuracy: 0.3700
# Epoch 3/18
# 67/67 [==============================] - 1s 11ms/step - loss: 1.9969 - accuracy: 0.3894 - val_loss: 1.8727 - val_accuracy: 0.4507
# Epoch 4/18
# 67/67 [==============================] - 1s 11ms/step - loss: 1.8156 - accuracy: 0.4471 - val_loss: 1.7597 - val_accuracy: 0.4693
# Epoch 5/18
# 67/67 [==============================] - 1s 11ms/step - loss: 1.6415 - accuracy: 0.4991 - val_loss: 1.6150 - val_accuracy: 0.5053
# Epoch 6/18
# 67/67 [==============================] - 1s 11ms/step - loss: 1.5264 - accuracy: 0.5333 - val_loss: 1.6117 - val_accuracy: 0.5053
# Epoch 7/18
# ...

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)

datagen = preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2)

datagen.fit(x_train)


MyCNN_hyper_learning_model3 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'), 
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(20, activation='relu')])

MyCNN_hyper_learning_model3.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


MyCNN_hyper_learning_History3 = MyCNN_hyper_learning_model3.fit(datagen.flow(x_train, y_train, subset="training"), epochs=18, batch_size=128,
                    validation_data=datagen.flow(x_train, y_train, subset="validation"), callbacks = [callback])

test_loss3, test_acc3 = MyCNN_hyper_learning_model3.evaluate(x_test,  y_test, verbose=2)
print(test_loss3, test_acc3)
# Out:
# Epoch 1/18
# 213/213 [==============================] - 7s 31ms/step - loss: 2.8191 - accuracy: 0.0859 - val_loss: 2.6508 - val_accuracy: 0.0994
# Epoch 2/18
# 213/213 [==============================] - 6s 30ms/step - loss: 2.5391 - accuracy: 0.0397 - val_loss: 2.4248 - val_accuracy: 0.0706
# Epoch 3/18
# 213/213 [==============================] - 6s 30ms/step - loss: 2.3745 - accuracy: 0.0537 - val_loss: 2.3196 - val_accuracy: 0.0265
# Epoch 4/18
# 213/213 [==============================] - 6s 30ms/step - loss: 2.2686 - accuracy: 0.0494 - val_loss: 2.3035 - val_accuracy: 0.0429
# 63/63 - 0s - loss: 3.1936 - accuracy: 0.0045
# 3.1935715675354004 0.0044999998062849045

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

datagen = preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.3)

datagen.fit(x_train)

MyCNN_hyper_learning_model4 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'), 
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dense(20, activation='relu')])

MyCNN_hyper_learning_model4.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


MyCNN_hyper_learning_History4 = MyCNN_hyper_learning_model4.fit(datagen.flow(x_train, y_train, subset="training"), epochs=18, batch_size=128,
                    validation_data=(datagen.flow(x_train, y_train, subset="validation")), callbacks = [callback])

test_loss4, test_acc4 = MyCNN_hyper_learning_model4.evaluate(x_test,  y_test, verbose=2)
print(test_loss4, test_acc4)
# Out:
# Epoch 1/18
# 186/186 [==============================] - 5s 26ms/step - loss: 2.7856 - accuracy: 0.0976 - val_loss: 2.7357 - val_accuracy: 0.1608
# Epoch 2/18
# 186/186 [==============================] - 5s 25ms/step - loss: 2.6763 - accuracy: 0.1207 - val_loss: 2.6586 - val_accuracy: 0.0506
# Epoch 3/18
# 186/186 [==============================] - 5s 25ms/step - loss: 2.6119 - accuracy: 0.1077 - val_loss: 2.6132 - val_accuracy: 0.1365
# Epoch 4/18
# 186/186 [==============================] - 5s 25ms/step - loss: 2.5598 - accuracy: 0.1444 - val_loss: 2.6314 - val_accuracy: 0.1459
# Epoch 5/18
# 186/186 [==============================] - 4s 24ms/step - loss: 2.4653 - accuracy: 0.1434 - val_loss: 2.5299 - val_accuracy: 0.0855
# Epoch 6/18
# 186/186 [==============================] - 4s 23ms/step - loss: 2.3976 - accuracy: 0.1516 - val_loss: 2.4617 - val_accuracy: 0.2549
# Epoch 7/18
# ...

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

MyCNN_hyper_learning_model5 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'), 
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(20, activation='relu')])

MyCNN_hyper_learning_model5.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


MyCNN_hyper_learning_History5 = MyCNN_hyper_learning_model5.fit(x_train, y_train, epochs=18, batch_size=128,
                    validation_data=(x_val, y_val), callbacks = [callback])

test_loss5, test_acc5 = MyCNN_hyper_learning_model5.evaluate(x_test,  y_test, verbose=2)
print(test_loss5, test_acc5)
# Out:
# Epoch 1/18
# 67/67 [==============================] - 1s 10ms/step - loss: 2.9079 - accuracy: 0.1196 - val_loss: 2.6671 - val_accuracy: 0.2380
# Epoch 2/18
# 67/67 [==============================] - 0s 6ms/step - loss: 2.5381 - accuracy: 0.2534 - val_loss: 2.3126 - val_accuracy: 0.3227
# Epoch 3/18
# 67/67 [==============================] - 0s 6ms/step - loss: 2.2809 - accuracy: 0.3346 - val_loss: 2.0977 - val_accuracy: 0.3907
# Epoch 4/18
# 67/67 [==============================] - 0s 7ms/step - loss: 2.1009 - accuracy: 0.3914 - val_loss: 2.0243 - val_accuracy: 0.4120
# Epoch 5/18
# 67/67 [==============================] - 0s 6ms/step - loss: 1.9697 - accuracy: 0.4239 - val_loss: 1.9381 - val_accuracy: 0.4347
# Epoch 6/18
# 67/67 [==============================] - 0s 7ms/step - loss: 1.8330 - accuracy: 0.4558 - val_loss: 1.7574 - val_accuracy: 0.4893
# Epoch 7/18
# ...

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

MyCNN_hyper_learning_model6 = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(20, activation='relu')])

MyCNN_hyper_learning_model6.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


MyCNN_hyper_learning_History6 = MyCNN_hyper_learning_model6.fit(x_train, y_train, epochs=18, batch_size=128,
                    validation_data=(x_val, y_val), callbacks = [callback])

test_loss6, test_acc6 = MyCNN_hyper_learning_model6.evaluate(x_test,  y_test, verbose=2)
print(test_loss6, test_acc6)
# Out:
# Epoch 1/18
# 67/67 [==============================] - 51s 17ms/step - loss: 2.8472 - accuracy: 0.1395 - val_loss: 2.7844 - val_accuracy: 0.2327
# Epoch 2/18
# 67/67 [==============================] - 1s 13ms/step - loss: 2.5063 - accuracy: 0.2504 - val_loss: 2.5458 - val_accuracy: 0.3220
# Epoch 3/18
# 67/67 [==============================] - 1s 13ms/step - loss: 2.2450 - accuracy: 0.3268 - val_loss: 2.3354 - val_accuracy: 0.3807
# Epoch 4/18
# 67/67 [==============================] - 1s 13ms/step - loss: 2.0748 - accuracy: 0.3781 - val_loss: 2.2678 - val_accuracy: 0.3807
# Epoch 5/18
# 67/67 [==============================] - 1s 13ms/step - loss: 1.9183 - accuracy: 0.4314 - val_loss: 2.1385 - val_accuracy: 0.4393
# Epoch 6/18
# 67/67 [==============================] - 1s 13ms/step - loss: 1.8287 - accuracy: 0.4576 - val_loss: 2.0443 - val_accuracy: 0.4567
# Epoch 7/18
# ...

# %% [markdown]
# Παρατηρούμε πως στα συγκεκριμένα δίκτυα ο πρόωρος τερματισμός δεν βοήθησε ιδιαίτερα στην βελτίωση της γενίκευσης του μοντέλου μας. Παρόλα αυτά είναι σίγουρα ένα χρήσιμο εργαλείο καθώς αποτρέπει την περιττή εκπαίδευση ενός συστήματος (πχ στο model3 που προσπαθήσαμε να εκπαιδεύσουμε παραπάνω, δεν υπήρξε σχεδόν καμία βελτίωση στις πρώτες γενιές και για αυτό σταμάτησε η εκπαίδευσή του), αλλά και θεωρητικά ο πρόωρος τερματισμός προστατεύει ένα σύστημα από το overfitting, μην αφήνωντάς το να "μάθει" ως χαρακτηριστικά μιας κατηγορίας πχ τον θόρυβο κτλ που μπορεί να συναντήσει στο training set. <br/>
# Το dropout ήταν το πιο χρήσιμο εργαλείο για την βελτίωση της γενίκευσης του δικού μας μοντέλου, καθώς εκεί παρατηρήσαμε τόσο την αύξυση όλων των ορθότήτων, όσο και τη μείωση της διάφορας της ορθότητας από την ορθότητα επικύρωσης και την ορθότητα των test. Αυτό είναι και λογικό, καθώς το dropout, δεν αφήνει τους νεωρώνες να έχουν έντονη εξάρτηση ο ένας από των άλλον, αφού σε κάθε εποχή υπάρχει πιθανότητα μερικοί από τους νευρώνες να μην "λειτουργήσουν". <br/>
# Τέλος, η επαύξηση δεδομένων δεν φάνηκε να βοηθάει το δικό μας μοντέλο. Στην πρώτη περίπτωση η προώρη εκπαίδευση σταμάτησε τη διαδικασία εκπαίδευσης καθώς δεν υπήρχε βελτίωση, ενώ στη δευτερή αν και οι ορθότητες ήταν καλύτερες από την πρώτη, εξακολουθούσαν να είναι χειρότερες από του αρχικού CNN (χωρίς κάποια προστασία για το overfitting) και η ορθότητα του testing ήταν και πάλι πολύ κακή. Αυτό φυσικά δεν σημαίνει πως η επαύξηση δεδομένων είναι μια κακή τεχνική, αλλά πως δεν βοήθησε το δικό μας μοντέλο, είτε επειδή είχαμε πολύ λίγες εποχές ενώ αυξήσαμε σημαντικά το πλήθος του dataset*, είτε από κάποιο δικό μας λάθος κατά τη διαδικασία εφαρμογής της.
#
# *Παραθέτουμε από κάτω το ίδιο μοντέλο με τι μόνη διαφορά πως το αφήνουμε να εκπαιδευτεί για 50 εποχές. H ορθότητα και η ορθότητα επικύρωσης συνεχώς βελτιώνονται παρόλα αυτά η ορθότητα των tests παραμένει πολύ κακή, άρα μάλλον δεν βοήθησε ιδιαίτερα στο generalization του μοντέλου.

# %%
datagen = preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.3)

datagen.fit(x_train)

MyCNN_hyper_learning_model_50_epoches = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'), 
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dense(20, activation='relu')])

MyCNN_hyper_learning_model_50_epoches.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


MyCNN_hyper_learning_History_50_epoches = MyCNN_hyper_learning_model_50_epoches.fit(datagen.flow(x_train, y_train, subset="training"), epochs=50, batch_size=128,
                    validation_data=(datagen.flow(x_train, y_train, subset="validation")))

test_loss_50_epoches, test_acc_50_epoches = MyCNN_hyper_learning_model_50_epoches.evaluate(x_test,  y_test, verbose=2)
print(test_loss_50_epoches, test_acc_50_epoches)
# Out:
# Epoch 1/50
# 186/186 [==============================] - 5s 23ms/step - loss: 2.8776 - accuracy: 0.0452 - val_loss: 2.8277 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 186/186 [==============================] - 4s 23ms/step - loss: 2.7706 - accuracy: 0.0435 - val_loss: 2.7611 - val_accuracy: 0.0431
# Epoch 3/50
# 186/186 [==============================] - 4s 23ms/step - loss: 2.7087 - accuracy: 0.0395 - val_loss: 2.6073 - val_accuracy: 7.8431e-04
# Epoch 4/50
# 186/186 [==============================] - 4s 23ms/step - loss: 2.5819 - accuracy: 0.0262 - val_loss: 2.5410 - val_accuracy: 0.0208
# Epoch 5/50
# 186/186 [==============================] - 4s 23ms/step - loss: 2.4952 - accuracy: 0.0489 - val_loss: 2.4164 - val_accuracy: 0.0494
# Epoch 6/50
# 186/186 [==============================] - 4s 22ms/step - loss: 2.4243 - accuracy: 0.0748 - val_loss: 2.4231 - val_accuracy: 0.0894
# Epoch 7/50
# ...

# %% [markdown]
# Γενικά, καλύτερα αποτελέσματα παρατηρήσαμε στα μοντέλα 5 και 6, στα οποία προσθέσαμε αρκετά επίπεδα dropout, καθώς το testing και το validation accuracy ήταν αρκετά κοντά στο training accuracy, σε αντίθεση με το αρχικό μοντέλο (ειδικά στο 5ο μοντέλο), αλλά και είχαν καλύτερες τιμές από το αρχικό μοντέλο (~0.43 στο αρχικό, ~0.57 στα μοντέλα 5 και 6). <br/>
# Με διαφορά χειρότερη επίδοση είχαν τα μοντέλα 3 και 4, στα οποία υπήρξε επαύξηση δεδομένων, αφού όχι μόνο οι ορθότητες ήταν πολύ χειρότερες από του αρχικού μοντέλου, αλλά δεν υπήρξε και καμία προστασία από overfitting (το test accuracy ήταν πάρα πολύ χειρότερο από το training και το validation). <br/>
# Τέλος, στα μοντέλα 1 και 2 τα accuracies είναι συνολικά καλύτερα από αυτά του αρχικού μοντέλου, αλλά το testing και το validation accuracy απέχουν αρκετά από το training accuracy.

# %% [markdown]
# Παρατήρηση: Καθώς το μοντέλο 5 φαίνεται να έχει αρκετά καλή προστασία από φαινόμενα overfitting, αλλά και να συνεχίζει να αυξάνει τo accuraccy του με το πέρασμα των εποχών, πιθανότατα να μπορούσαμε να το εκπαιδεύσουμε για ακόμα περισσότερες εποχές και να είχαμε ακόμα καλύτερα αποτελέσματα.

# %% [markdown]
# ## Ερώτημα 3
# ---
# ### Βήμα 1: Μεταφορά γνώσης
# Εφαρμόστε μεταφορά γνώσης (transfer learning) στο δικό σας μοντέλο (**MyCNN**), που αξιολογήσατε ως καλύτερο προς την ακρίβεια στην αντιμετώπιση της υπερεκπαίδεσης.
#
# Για το transfer learning επιλέξτε το [VGG16](https://www.tensorflow.org/api_docs/python/tf/keras/applications/vgg16) για μεταφορά μάθησης.
#
# 1. "Παγώστε" τη συνελικτική βάση και εκπαιδεύστε την κεφαλή ταξινόμησης (classification head - σημαία trainable = False).
#
# 2. Εκπαιδέστε μόνο ένα ποσοστό των επιπέδων, το οποίο βρίσκεται προς την έξοδο του δικτύου. Οι σημαίες trainable εδώ θα πρέπει να οριστούν ανά επίπεδο.
#
# 3. Αξιολογήστε τα αποτελέσματά σας, βάσει της ορθότητας του validation set και του test set σας.

# %%
# !pip install -U tf-hub-nightly
# !pip install tfds-nightly
import tensorflow_hub as hub
# Out:
# ...
#      |████████████████████████████████| 112kB 8.5MB/s
# ...
#      |████████████████████████████████| 4.0MB 8.1MB/s
# ...

# %%
#Training only our top layers


pretrained_model = tf.keras.applications.VGG16(input_shape=(32,32,3), include_top=False)
pretrained_model.trainable = False

tl_model1 = models.Sequential([
  pretrained_model,
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(20, activation='relu')])

tl_model1.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


tl_History1 = tl_model1.fit(x_train, y_train, epochs=18, batch_size=128,
                    validation_data=(x_val, y_val))

test_loss1, test_acc1 = tl_model1.evaluate(x_test,  y_test, verbose=2)
print(test_loss1, test_acc1)
# Out:
# Epoch 1/18
# 67/67 [==============================] - 2s 24ms/step - loss: 2.6657 - accuracy: 0.2166 - val_loss: 2.2242 - val_accuracy: 0.3873
# Epoch 2/18
# 67/67 [==============================] - 1s 21ms/step - loss: 2.1953 - accuracy: 0.3726 - val_loss: 1.9660 - val_accuracy: 0.4280
# Epoch 3/18
# 67/67 [==============================] - 1s 21ms/step - loss: 1.9626 - accuracy: 0.4326 - val_loss: 1.7255 - val_accuracy: 0.5033
# Epoch 4/18
# 67/67 [==============================] - 1s 20ms/step - loss: 1.7667 - accuracy: 0.4782 - val_loss: 1.6403 - val_accuracy: 0.5287
# Epoch 5/18
# 67/67 [==============================] - 1s 21ms/step - loss: 1.6434 - accuracy: 0.5174 - val_loss: 1.5836 - val_accuracy: 0.5373
# Epoch 6/18
# 67/67 [==============================] - 1s 21ms/step - loss: 1.5502 - accuracy: 0.5312 - val_loss: 1.5191 - val_accuracy: 0.5347
# Epoch 7/18
# ...

# %% [markdown]
# Παρατηρούμε πως οι τιμές των ορθοτήτων είναι καλύτερες από του αρχικού μοντέλου, αλλά όχι από του μοντέλου με την αντιμετώπιση της υπερεκπαίδεσης. Εν μέρη, αυτό μπορεί να ευθύνεται και στο ότι το VGG16 έχει εκπαιδευτεί πάνω σε εικόνες του ImageNet που είναι διαφορετικές από αυτές του cifar-100 που χρησιμοποιούμε

# %%
#Training our top layers and some of the top layers of VGG16

pretrained_model = tf.keras.applications.VGG16(input_shape=(32,32,3), include_top=False)

#Number of layers in pretrained model
print(len(pretrained_model.layers[:]))

#We train the top 9 layers of VGG16 
i = 1
for layer in pretrained_model.layers[:]:
  if (i <= 14):
    layer.trainable = False 
  else:
    layer.trainable = True
  i = i + 1

tl_model2 = models.Sequential([
  pretrained_model,
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Dense(20, activation='relu')])

tl_model2.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


tl_History2 = tl_model2.fit(x_train, y_train, epochs=18, batch_size=128,
                    validation_data=(x_val, y_val))

test_loss2, test_acc2 = tl_model2.evaluate(x_test,  y_test, verbose=2)
print(test_loss2, test_acc2)
# Out:
# 19
# Epoch 1/18
# 67/67 [==============================] - 3s 35ms/step - loss: 2.8459 - accuracy: 0.1284 - val_loss: 2.5700 - val_accuracy: 0.2433
# Epoch 2/18
# 67/67 [==============================] - 2s 30ms/step - loss: 2.3803 - accuracy: 0.3036 - val_loss: 2.1312 - val_accuracy: 0.3853
# Epoch 3/18
# 67/67 [==============================] - 2s 30ms/step - loss: 1.8698 - accuracy: 0.4575 - val_loss: 1.6878 - val_accuracy: 0.5093
# Epoch 4/18
# 67/67 [==============================] - 2s 30ms/step - loss: 1.4762 - accuracy: 0.5538 - val_loss: 1.4534 - val_accuracy: 0.5760
# Epoch 5/18
# 67/67 [==============================] - 2s 30ms/step - loss: 1.2219 - accuracy: 0.6301 - val_loss: 1.3233 - val_accuracy: 0.6020
# Epoch 6/18
# 67/67 [==============================] - 2s 30ms/step - loss: 1.0211 - accuracy: 0.6961 - val_loss: 1.3064 - val_accuracy: 0.6240
# Epoch 7/18
# ...

# %% [markdown]
# Στην περίπτωση που εκπαίδευουμε και μερικά από τα τελευταία layers του VGG16, παρατηρούμε σημαντική αύξηση στις ορθότητες, τιμές οι οποίες θα ήταν δύσκολο να πετύχουμε με το μικρό dataset που χρησιμοποιούσαμε χωρίς κάποιο transfer learning.

# %% [markdown]
# ## Διαχείριση μνήμης (TFRecord)
# Η φόρτωση δεδομένων με τον τρόπο που το κάναμε παραπάνω στο απλό παράδειγμα υλοποίησης είναι πολύ βολική αλλά δεν είναι αποτελεσματική ως προς τη διαχείριση της μνήμης. Συγκεκριμένα, με τον τρόπο αυτό, τα δεδομένα αποθηκεύονται απευθείας σε μεταβλητές, οι οποίες όλες μαζί καταλαμβάνουν τη RAM της CPU ή της GPU, κάτι που κάνει αδύνατη τη διαχείριση μεγάλων datasets ή τον μεταχηματισμό των δεδομένων όπως όταν κάνουμε αύξηση δεδομένων (data augmentation).
#
# Για να παρακαμφθεί αυτό το πρόβλημα, υπάρχει η δυνατότητα της σειριοποίησης των δεδομένων (serialization) και της αποθήκευσής τους σε αρχεία μεσαίου μεγέθους (κάποιων MB) τα οποία μπορούν να αναγνωστούν γραμμικά.
#
# Το φορμάτ TFRecord είναι ένα φορμάτ που επιτρέπει την αποθήκευση σειράς δυαδικών εγγραφών. Διαβάστε σχετικά για το [TFRecord and tf.Example](https://www.tensorflow.org/tutorials/load_data/tfrecord) και [tf.data: Build TensorFlow input pipelines](https://www.tensorflow.org/guide/data).
#
# Σημειώστε ότι με τη μέθοδο αυτή θα πρέπει να γίνει import η `tensorflow_datasets` και να χρησιμοποιήσουμε την `tfds.load` ώστε να αποθηκευθεί το σύνολο δεδομένων σε αρχεία tfrecord στο δίσκο (δείτε [εδώ](https://colab.research.google.com/github/tensorflow/datasets/blob/master/docs/overview.ipynb) ένα παράδειγμα). Φυσικά μπορούμε να μετατρέψουμε και τα πρωτογενή δεδομένα (raw data) του dataset όπως αρχεία jpg σε φορματ tfrecord όπως [εδώ](https://towardsdatascience.com/working-with-tfrecords-and-tf-train-example-36d111b3ff4d).
